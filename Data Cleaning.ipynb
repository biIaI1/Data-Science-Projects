# %% [markdown]
# # Welcome!

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Loading up the Video Games Sales Dataset

# %% [markdown]
# ### The Main Focus is to grasp the main idea of the dataset to handle Data types And, Identifying Missing Values.

# %%
df = pd.read_csv(r"C:\Users\HP\Downloads\vgsales.csv\vgsales.csv")
df.head(7)
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                    Tetris       GB  1989.0        Puzzle  Nintendo
# 6     7     New Super Mario Bros.       DS  2006.0      Platform  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37
# ...

# %%
df.sample(15)
# Out:
#         Rank                               Name Platform    Year  \
# 7054    7056                           Airblade      PS2  2001.0
# 15571  15574                         WorldShift       PC  2009.0
# 3627    3629  Lunar: Silver Star Story Complete       PS  1998.0
# 15991  15994            Donkey Kong Jungle Beat      Wii  2008.0
# 12131  12133                             Tropix       DS  2008.0
# 10862  10864                         Terranigma     SNES  1995.0
# 2220    2222                    Nickelodeon Fit      Wii  2010.0
# 5327    5329                  Aggressive Inline      PS2  2002.0
# 10203  10205       Shin Sangoku Musou 6 Special      PSP  2011.0
# 3570    3572              NCAA March Madness 07      PS2  2007.0
# 6505    6507     The Elder Scrolls IV: Oblivion       PC  2006.0
# 8791    8793   Frogger's Adventures: The Rescue       GC  2003.0
# 9359    9361                    Puzzle Kingdoms       DS  2009.0
# ...

# %%
df.shape
# Out:
# (16598, 11)

# %%
df.isna().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
df['Year'] = df['Year'].astype('Int64')

# %%
df['Year']=df['Year'].fillna(np.nan)

# %% [markdown]
# #### Handled missing Year values appropriately using NaN rather than introducing misleading numerical estimates.

# %% [markdown]
# #### Same for Publisher column.

# %%
df['Publisher'].isna().sum()
# Out:
# 58

# %%
df['Publisher'] = df['Publisher'].fillna(np.nan)

# %% [markdown]
# #### Last check-up before wraping up.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  Int64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: Int64(1), float64(5), int64(1), object(4)
# memory usage: 1.4+ MB
